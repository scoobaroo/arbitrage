# %%
import csv
import re
with open('/home/eric/Desktop/cs298/BUFFER1.CSV') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        print(row[1])
#         binance = row[4].split(',')
#         p = re.compile(r'\d+\.\d+')  # Compile a pattern to capture float values
#         binanceAcctValueUSD = [float(i) for i in p.findall(binance[0])]  # Convert strings to float
#         if(len(binanceAcctValueUSD)>0):
#             print(binanceAcctValueUSD[0])
#         withoutBot = row[3].split(',')
#         withoutBotValueUSD = [float(i) for i in p.findall(withoutBot[1])]
#         print(withoutBotValueUSD[0])
# Out:
# BTC  ZEN  ETH  STRAT  BTC
# BTC  QTUM  ETH  BTC
# BTC  HC  ETH  NANO  BTC
# BTC  ZEN  ETH  KMD  BTC
# BTC  MTL  ETH  USDT  BTC
# BTC  ZEN  ETH  MTL  BTC
# BTC  MTL  ETH  PIVX  BTC
# BTC  ONT  ETH  ZEN  BTC
# BTC  WAN  ETH  REP  BTC
# BTC  WAN  ETH  USDT  BTC
# BTC  AE  ETH  USDT  QTUM  BTC
# BTC  NEBL  ETH  USDT  BTC
# BTC  NEO  ETH  SALT  BTC
# BTC  KMD  ETH  USDT  BTC
# BTC  EDO  ETH  USDT  BTC
# BTC  VIA  ETH  BTC
# BTC  STEEM  ETH  BTC
# BTC  LUN  ETH  USDT  BTC
# BTC  ZEN  ETH  REP  BTC
# BTC  LUN  ETH  USDT  BNB  NANO  BTC
# BTC  ETH  STEEM  BTC
# BTC  ICX  USDT  BTC
# BTC  MCO  ETH  TRIG  BTC
# BTC  ZEN  BNB  LTC  USDT  ETH  REP  BTC
# BTC  ICX  USDT  BCC  BTC
# BTC  ZEN  BNB  BTC
# BTC  ZEN  ETH  BTC
# BTC  ZEN  ETH  SKY  BTC
# BTC  ZEN  ETH  USDT  BTC
# BTC  ZEN  ETH  BTC
# BTC  TRIG  ETH  BTC
# BTC  TRIG  ETH  CLOAK  BTC
# BTC  RLC  ETH  MTL  BTC
# BTC  RLC  ETH  KMD  BTC
# BTC  ZEN  ETH  BTC
# BTC  KMD  ETH  LUN  BTC
# BTC  ZEN  BNB  ETH  WAN  BTC
# ...

# %%
with open('/home/eric/Desktop/cs298/BUFFER2.CSV') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
#         print(row[1])
#         binance = row[4].split(',')
#         p = re.compile(r'\d+\.\d+')  # Compile a pattern to capture float values
#         binanceAcctValueUSD = [float(i) for i in p.findall(binance[0])]  # Convert strings to float
#         if(len(binanceAcctValueUSD)>0):
#             print(binanceAcctValueUSD[0])
        withoutBot = row[3].split(',')
        withoutBotValueUSD = [float(i) for i in p.findall(withoutBot[1])]
        print(withoutBotValueUSD[0])
# Out:
# 2530.252936547334
# 2524.9779610274973
# 2526.491793103963
# 2534.0878015575704
# 2533.4926055500014
# 2532.2293403924737
# 2532.456394424089
# 2533.3530818609474
# 2533.5663793016533

# %%
with open('/home/eric/Desktop/cs298/BUFFER3.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
#         print(row[0])
#         binance = row[4].split(',')
#         p = re.compile(r'\d+\.\d+')  # Compile a pattern to capture float values
#         binanceAcctValueUSD = [float(i) for i in p.findall(binance[0])]  # Convert strings to float
#         if(len(binanceAcctValueUSD)>0):
#             print(binanceAcctValueUSD[0])
        withoutBot = row[3].split(',')
        withoutBotValueUSD = [float(i) for i in p.findall(withoutBot[1])]
        print(withoutBotValueUSD[0])
# Out:
# 2533.860770370909
# 2543.4066183090154
# 2555.5481148858053
# 2562.3590719660233
# 2563.010245251578
# 2567.565159620049
# 2562.217667507164
# 2565.5897689324233
# 2562.9162748527456
# 2568.118681957631
# 2569.489220051082
# 2574.5533847526535
# 2568.7428478645907
# 2560.2030532784697
# 2563.2867560091886
# 2574.5917100466304
# 2569.344522727084
# 2574.1515670034655
# 2580.088571077303

# %%
with open('/home/eric/Desktop/cs298/BUFFER4.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
#         print(row[0])
#         binance = row[4].split(',')
#         p = re.compile(r'\d+\.\d+')  # Compile a pattern to capture float values
#         binanceAcctValueUSD = [float(i) for i in p.findall(binance[0])]  # Convert strings to float
#         if(len(binanceAcctValueUSD)>0):
#             print(binanceAcctValueUSD[0])
        withoutBot = row[3].split(',')
        withoutBotValueUSD = [float(i) for i in p.findall(withoutBot[1])]
        print(withoutBotValueUSD[0])
# Out:
# 2598.3626561717856
# 2592.5631601401146
# 2587.8693260167984
# 2592.9790564944888
# 2595.009982664824
# 2595.964273350838
# 2576.3440685927753
# 2576.8441349811123
# 2581.094291305423
# 2578.2658740383586
# 2594.9440849608927
# 2551.733116908215
# 2552.429999242396
# 2551.1869395201334
# 2547.043751902554
# 2539.8787705710074
# 2537.7662349349525
# 2529.8539091582547
# 2524.6350215847774
# 2518.047442005828
# 2518.3771812440423
# 2519.3539858147733
# 2513.749951201104
# 2483.2460569113205
# 2471.8987178582165
# 2473.8154274200597
# 2474.876843176043
# 2477.7231352115377
# 2480.869614350089
# 2484.4279302183354
# 2485.965404917394
# 2484.949641695621
# 2486.3973281824888
# 2479.883317504486
# 2474.47766599604
# 2475.1829044944693
# 2473.6570820166103
# 2468.215450426288
# 2468.5803566636905
# 2468.7794266115006
# 2463.055020107076
# 2462.495745912257
# 2457.8616045064705
# 2458.2207560088727
# 2479.505753439438
# 2489.5227198401312
# 2487.1184283665584
# 2488.5554443275414
# ...
